# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

random_data = np.random.randn(100)  

sns.boxplot(y=random_data) 

plt.title("Seaborn Boxplot of Random Data")
plt.show()
